# %% [markdown]
# # 04 - Simulation Analysis
#
# Exploration only. Reusable logic graduates into `src/worldcup/simulation/`.
#
# **Goal:** turn Monte Carlo output into the headline result and sanity-check it.
#
# TODO (slices 6, 7):
# - run `simulate_tournament`; inspect title / advancement probabilities
# - Monte Carlo convergence (probabilities stable as n_simulations grows)
# - compare against market-implied odds as an external sanity check
