# %% [markdown]
# # 02 - Feature Engineering
#
# Exploration only. Reusable logic graduates into `src/worldcup/features/`.
#
# **Goal:** prototype as-of-date features and visually confirm there is no leakage.
#
# TODO (slice 3):
# - Elo trajectory per team over time
# - rolling form / goals (via `add_rolling_mean`), rest days, ranking deltas
# - spot-check that no feature uses post-kickoff information
