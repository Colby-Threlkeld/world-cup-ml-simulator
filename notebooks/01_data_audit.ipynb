# %% [markdown]
# # 01 - Data Audit
#
# Exploration only. Reusable logic graduates into `src/worldcup/`; nothing here is imported by the package or tests.
#
# **Goal:** sanity-check the raw international results + FIFA ranking datasets.
#
# TODO (slice 1):
# - row counts, date range, missing values
# - team-name mismatches across sources (feed into `configs/team_name_map.yaml`)
# - home/away/neutral distribution, score distributions
# - duplicate-match check
