# %% [markdown]
# # 03 - Model Training
#
# Exploration only. Reusable logic graduates into `src/worldcup/models/`.
#
# **Goal:** compare the Poisson goals model against the Elo baseline with proper scoring rules.
#
# TODO (slices 2, 4, 5):
# - temporal backtest of the Elo baseline (Brier, log loss)
# - fit the Poisson goals model; must beat the baseline
# - calibration + reliability diagrams
